# %%
# As usual, a bit of setup

import time, os, json
import numpy as np
from scipy.misc import imread, imresize
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
sa_value, sa_counts = start_games(5000000)
# Out:
# Playing game number:  0
# 0.47276 0.5
# Playing game number:  100000
# 0.49017 0.333333333333
# Playing game number:  200000
# 0.49647 0.25
# Playing game number:  300000
# 0.49198 0.2
# Playing game number:  400000
# 0.49681 0.166666666667
# Playing game number:  500000
# 0.49674 0.142857142857
# Playing game number:  600000
# 0.4977 0.125
# Playing game number:  700000
# 0.49798 0.111111111111
# Playing game number:  800000
# 0.49625 0.1
# Playing game number:  900000
# 0.49578 0.0909090909091
# Playing game number:  1000000
# 0.49737 0.0833333333333
# Playing game number:  1100000
# 0.49934 0.0769230769231
# Playing game number:  1200000
# 0.50041 0.0714285714286
# Playing game number:  1300000
# 0.49711 0.0666666666667
# Playing game number:  1400000
# 0.50011 0.0625
# Playing game number:  1500000
# 0.50106 0.0588235294118
# Playing game number:  1600000
# 0.49825 0.0555555555556
# Playing game number:  1700000
# 0.50454 0.0526315789474
# Playing game number:  1800000
# ...

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np
from easy21 import start_games

fig = plt.figure()
ax = fig.gca(projection='3d')

X = np.arange(1, 22)
Y = np.arange(1, 11)
stick = sa_value[:,:,0]
hit = sa_value[:,:,1]

s_counts = sa_counts[:,:,0]
h_counts = sa_counts[:,:,1]
X, Y = np.meshgrid(X, Y)

surf = ax.plot_surface(Y, X, stick, linewidth=0, antialiased=True, rstride=1, cstride=1, shade=True, color='r', alpha=0.6)
plt.show()
# Out:
# <class 'matplotlib.figure.Figure'>
# <class 'matplotlib.axes._subplots.Axes3DSubplot'>
# (10, 21, 2)

# %%
print np.sum(s_counts)
print np.sum(h_counts)
# Out:
# 59430.0
# 217376.0

# %%
print np.sum(h_counts) + np.sum(s_counts)
# Out:
# 1344318.0
